# %%
from openpile.construct import Pile, SoilProfile, Layer, Model
from openpile.soilmodels import API_clay, API_sand, frankeRollins2013
from openpile.analyze import winkler
from scipy.optimize import fsolve

import pandas as pd
import os

# %%
# Get the current working directory
cwd = os.getcwd()
# Read the CSV file (replace 'filename.csv' with your actual file name)
dfPileConfig = pd.read_csv(os.path.join(cwd, 'pileConfig-pier1-static.csv'))
dfPileConfig.index.name = 'id'
dfPileConfig
# Out:
#     diameter[m]  length[m]  factored-axial-load[kN]  initial-lateral-load[kN]
# id
# 0           1.5         30                     7280                       185
# 1           1.5         35                     9275                       180
# 2           1.5         40                    11260                       180
# 3           1.5         45                    13245                       175
# 4           1.5         50                    15225                       170
# 5           2.0         30                    10370                       475
# 6           2.0         35                    13045                       470
# 7           2.0         40                    15715                       470
# 8           2.0         45                    18380                       465
# 9           2.0         50                    21035                       465
# 10          2.5         30                    13785                       970
# 11          2.5         35                    17160                       960
# 12          2.5         40                    20520                       960
# 13          2.5         45                    23870                       955
# 14          2.5         50                    27210                       950

# %%
sp = SoilProfile(
    name="pier1-Static",
    top_elevation=0.0,
    water_line=14.80,
    layers=[
        Layer(
            name="L. to M.Dense Clean Sand Φ=31°, γsat=17kN/m³",
            top=0,
            bottom=-6.0,
            weight=17.0,
            lateral_model=API_sand(phi=31, kind="static"),
        ),
        Layer(
            name="M.Dense Silty Sand Φ=35°, γsat=18kN/m³",
            top=-6.0,
            bottom=-12.0,
            weight=18.0,
            lateral_model=API_sand(phi=35, kind="static", georgiadis = True,  d_adj = -1.490280463302738),
        ),
        Layer(
            name="M. to Dense Clean Sand Φ=36°, γsat=18kN/m³",
            top=-12.0,
            bottom=-18.0,
            weight=18.0,
            lateral_model=API_sand(phi=36, kind="static", georgiadis = True,  d_adj = -2.130122267621226),
        ),
        Layer(
            name="Dense Silty Sand Φ=37°, γsat=19kN/m³",
            top=-18.0,
            bottom=-24.0,
            weight=19.0,
            lateral_model=API_sand(phi=37, kind="static", georgiadis = True,  d_adj = -3.0639344827240724),
        ),
        Layer(
            name="Hard Clay Su=192kPa, eps=0.32%, γsat=20kN/m³",
            top=-24.0,
            bottom=-30.0,
            weight=20.0,
            lateral_model=API_clay(Su=192, eps50=0.32/100, kind="static"),
        ),
        Layer(
            name="D. to V.Dense Sand Φ=39°, γsat=19kN/m³",
            top=-30.0,
            bottom=-60.0,
            weight=19.0,
            lateral_model=API_sand(phi=39, kind="static", georgiadis = True,  d_adj = -14.577773130626385),
        ),
    ],
)

# %%
# List solved shear values
solutions = []

for index, row in dfPileConfig.iterrows():
    print(f"""
          
          ========================================================================
          diameter: {row['diameter[m]']} m\t length: {row['length[m]']} m
          ========================================================================

          """)

    p = Pile(name = "pier1-static",
        kind='Solid-Circle',
        material='Concrete',
        top_elevation = 14.80,
        pile_sections={
            'length': [row['length[m]'] + 14.80],
            'diameter': [row['diameter[m]']],
            'wall thickness': [1e-10],
            # 'E': [24_870_062.324 ], # Young's Modulus
            # 'area': [1.767146],
            # 'I': [2.48505],
            # 'width': [1.5],
            # 'tip_area': [ 1.767146]
            
        }
    )

    # Create Model
    M = Model(name="pier1-static", 
            pile=p, 
            soil=sp, 
            element_type="Timoshenko",
            coarseness=0.5)
    
    # Apply bottom fixity along x-axis
    M.set_support(elevation= (-1 * row['length[m]']), Tx=True)
    M.set_support(elevation=14.80, Rz=True)

    axial = row['factored-axial-load[kN]']

    M.set_pointload(elevation=14.80, Px=-axial)
    M.set_pointdisplacement(elevation=14.80, Ty=0.024999)

    Result = winkler(M)

    topDeflection = Result.deflection['Deflection [m]'].iloc[0]

    topShear = Result.forces[["V [kN]"]].iloc[0]

    print(f"\nSolved shear value corresponding to {topDeflection} mm deflection: {topShear[0]:.4f} kN\n")

    solutions.append(topShear.iloc[0])

    # # Solve for shear load
    # def analysis(axial, shear):

    #     M.set_pointload(elevation=14.80, Px=axial, Py=shear)
    #     # Run analysis

    #     Result = winkler(M)

    #     print(f"Axial: {axial} kN\tShear: {float(shear):.4f} kN\tDeflection: {float(Result.deflection['Deflection [m]'].iloc[0])*1000:.4f} mm")

    #     return Result.deflection['Deflection [m]'].iloc[0] 

    # goal = 0.024999  # allowable deflection of 0.025 m

    # solution = fsolve(lambda x: analysis(axial = row['factored-axial-load[kN]'], shear = x) - goal, x0=row['initial-lateral-load[kN]'],xtol=1e-3, maxfev=4)

    # print(f"\nSolved shear value corresponding to {goal*1000} mm deflection: {solution[0]:.4f} kN\n")

    # solutions.append(solution[0])  # Append the solution to the list

# Add solutions as a new column to the DataFrame
dfPileConfig['solved-lateral-load[kN]'] = solutions
# Out:
#
#           ========================================================================
#           diameter: 1.5 m	 length: 30.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 175.8039 kN
#
#
#
#           ========================================================================
#           diameter: 1.5 m	 length: 35.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 173.2744 kN
#
#
#
#           ========================================================================
#           diameter: 1.5 m	 length: 40.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 170.7545 kN
#
#
#
#           ========================================================================
#           diameter: 1.5 m	 length: 45.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 168.2315 kN
#
#
#
#           ========================================================================
#           diameter: 1.5 m	 length: 50.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 165.7118 kN
#
#
#
#           ========================================================================
#           diameter: 2.0 m	 length: 30.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 450.1814 kN
#
#
#
#           ========================================================================
#           diameter: 2.0 m	 length: 35.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 447.1171 kN
#
#
#
#           ========================================================================
#           diameter: 2.0 m	 length: 40.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 444.0564 kN
#
#
#
#           ========================================================================
#           diameter: 2.0 m	 length: 45.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 440.9994 kN
#
#
#
#           ========================================================================
#           diameter: 2.0 m	 length: 50.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 437.9518 kN
#
#
#
#           ========================================================================
#           diameter: 2.5 m	 length: 30.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 908.1212 kN
#
#
#
#           ========================================================================
#           diameter: 2.5 m	 length: 35.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 904.5434 kN
#
#
#
#           ========================================================================
#           diameter: 2.5 m	 length: 40.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 900.9798 kN
#
#
#
#           ========================================================================
#           diameter: 2.5 m	 length: 45.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 897.4252 kN
#
#
#
#           ========================================================================
#           diameter: 2.5 m	 length: 50.0 m
#           ========================================================================
#
#
# Converged at iteration no. 2
#
# Solved shear value corresponding to 0.024999 mm deflection: 893.8796 kN

# %%
dfPileConfig.to_clipboard(index=True)

# %%
deflectionList = []
forceList = []
pySpringList = []
modelList = []
resultList = []

for index, row in dfPileConfig.iterrows():  


    p = Pile(name = "pier1-static",
        kind='Solid-Circle',
        material='Concrete',
        top_elevation = 14.80,
        pile_sections={
            'length': [row['length[m]'] + 14.80],
            'diameter': [row['diameter[m]']],
            'wall thickness': [1e-10],
            'E': [24_870_062.324], # Young's Modulus
            # 'area': [1.767146],
            # 'I': [2.48505],
            # 'width': [1.5],
            # 'tip_area': [ 1.767146]
            
        }
    )

    # Create Model
    M = Model(name=f"pier1-static-fixed-{row['diameter[m]']}D-{row['length[m]']}L:", 
            pile=p, 
            soil=sp, 
            element_type="Timoshenko",
            coarseness=0.5)
    
    # Apply bottom fixity along x-axis
    M.set_support(elevation= (-1 * row['length[m]']), Tx=True)
    M.set_support(elevation=14.80, Rz=True)

    M.set_pointload(elevation=14.80, Px=-row['factored-axial-load[kN]'], Py=row['solved-lateral-load[kN]'])
    # Run analysis

    Result = winkler(M)

    print(f"""
        id: {index}\tdiameter: {row['diameter[m]']} m\tlength: {row['length[m]']} m\tAxial: {row['factored-axial-load[kN]']} kN\tShear: {row['solved-lateral-load[kN]']:.4f} kN\tDeflection: {float(Result.deflection['Deflection [m]'].iloc[0])*1000:.4f} mm
        """)
    
    deflectionList.append(Result.deflection)  # Append the solution to the list
    forceList.append(Result.forces)
    pySpringList.append(M.get_py_springs(kind='element'))
    modelList.append(M)
    resultList.append(Result)
# Out:
# Converged at iteration no. 2
#
#         id: 0	diameter: 1.5 m	length: 30.0 m	Axial: 7280.0 kN	Shear: 175.8039 kN	Deflection: 25.0833 mm
# c:\Users\AMH-L143\anaconda3\envs\openPile-mk2\lib\site-packages\pandas\core\frame.py:3678: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead.  To get a de-fragmented frame, use `newframe = frame.copy()`
#   self[col] = igetitem(value, i)
# Converged at iteration no. 2
#
#         id: 1	diameter: 1.5 m	length: 35.0 m	Axial: 9275.0 kN	Shear: 173.2744 kN	Deflection: 25.1077 mm
#
# Converged at iteration no. 2
#
#         id: 2	diameter: 1.5 m	length: 40.0 m	Axial: 11260.0 kN	Shear: 170.7545 kN	Deflection: 25.1324 mm
#
# Converged at iteration no. 2
#
#         id: 3	diameter: 1.5 m	length: 45.0 m	Axial: 13245.0 kN	Shear: 168.2315 kN	Deflection: 25.1577 mm
#
# Converged at iteration no. 2
#
#         id: 4	diameter: 1.5 m	length: 50.0 m	Axial: 15225.0 kN	Shear: 165.7118 kN	Deflection: 25.1835 mm
#
# Converged at iteration no. 2
#
#         id: 5	diameter: 2.0 m	length: 30.0 m	Axial: 10370.0 kN	Shear: 450.1814 kN	Deflection: 25.0409 mm
#
# Converged at iteration no. 2
#
#         id: 6	diameter: 2.0 m	length: 35.0 m	Axial: 13045.0 kN	Shear: 447.1171 kN	Deflection: 25.0520 mm
#
# Converged at iteration no. 2
#
#         id: 7	diameter: 2.0 m	length: 40.0 m	Axial: 15715.0 kN	Shear: 444.0564 kN	Deflection: 25.0632 mm
#
# Converged at iteration no. 2
#
#         id: 8	diameter: 2.0 m	length: 45.0 m	Axial: 18380.0 kN	Shear: 440.9994 kN	Deflection: 25.0745 mm
#
# Converged at iteration no. 2
#
#         id: 9	diameter: 2.0 m	length: 50.0 m	Axial: 21035.0 kN	Shear: 437.9518 kN	Deflection: 25.0859 mm
#
# Converged at iteration no. 2
#
#         id: 10	diameter: 2.5 m	length: 30.0 m	Axial: 13785.0 kN	Shear: 908.1212 kN	Deflection: 25.0244 mm
#
# Converged at iteration no. 2
#
#         id: 11	diameter: 2.5 m	length: 35.0 m	Axial: 17160.0 kN	Shear: 904.5434 kN	Deflection: 25.0307 mm
#
# Converged at iteration no. 2
#
#         id: 12	diameter: 2.5 m	length: 40.0 m	Axial: 20520.0 kN	Shear: 900.9798 kN	Deflection: 25.0371 mm
#
# Converged at iteration no. 2
#
#         id: 13	diameter: 2.5 m	length: 45.0 m	Axial: 23870.0 kN	Shear: 897.4252 kN	Deflection: 25.0435 mm
#
# Converged at iteration no. 2
#
#         id: 14	diameter: 2.5 m	length: 50.0 m	Axial: 27210.0 kN	Shear: 893.8796 kN	Deflection: 25.0499 mm

# %%
import pickle

with open('pier1-static/dfPileConfig.pkl', 'wb') as file:
    pickle.dump(dfPileConfig, file)
with open('pier1-static/deflectionList.pkl', 'wb') as file:
    pickle.dump(deflectionList, file)
with open('pier1-static/forceList.pkl', 'wb') as file:
    pickle.dump(forceList, file)
with open('pier1-static/pySpringList.pkl', 'wb') as file:
    pickle.dump(pySpringList, file)
with open('pier1-static/modelList.pkl', 'wb') as file:
    pickle.dump(modelList, file)
with open('pier1-static/resultList.pkl', 'wb') as file:
    pickle.dump(resultList, file)

# %%
import pickle

# Load from file
with open('pier1-static/dfPileConfig.pkl', 'rb') as file:
    dfPileConfig = pickle.load(file)
with open('pier1-static/deflectionList.pkl', 'rb') as file:
    deflectionList = pickle.load(file)
with open('pier1-static/forceList.pkl', 'rb') as file:
    forceList = pickle.load(file)
with open('pier1-static/pySpringList.pkl', 'rb') as file:
    pySpringList = pickle.load(file)
with open('pier1-static/modelList.pkl', 'rb') as file:
    modelList = pickle.load(file)
with open('pier1-static/resultList.pkl', 'rb') as file:
    resultList = pickle.load(file)

# %%
# dfPileConfig.to_clipboard(index=True)
# forceList[9].to_clipboard(index=True)
# deflectionList[9].to_clipboard(index=True)
pySpringList[9].to_clipboard(index=True)
# modelList[9].plot()

# %%
modelList[9].plot()

# %%
pySpringList[9].to_clipboard(index=True)

# %%
modelList[9].plot()

# %%
resultList[9].plot()

# %%
print(modelList[9])
# Out:
#      x_top [m]  x_bottom [m]  y_top [m]  y_bottom [m]  Diameter [m]  Wall thickness [m]  Area [m2]    I [m4]       E [kPa]
# 0       14.800        14.307        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 1       14.307        13.813        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 2       13.813        13.320        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 3       13.320        12.827        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 4       12.827        12.333        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 5       12.333        11.840        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 6       11.840        11.347        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 7       11.347        10.853        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 8       10.853        10.360        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 9       10.360         9.867        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 10       9.867         9.373        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 11       9.373         8.880        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 12       8.880         8.387        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 13       8.387         7.893        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 14       7.893         7.400        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 15       7.400         6.907        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 16       6.907         6.413        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 17       6.413         5.920        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 18       5.920         5.427        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 19       5.427         4.933        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 20       4.933         4.440        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 21       4.440         3.947        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 22       3.947         3.453        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 23       3.453         2.960        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 24       2.960         2.467        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 25       2.467         1.973        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 26       1.973         1.480        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 27       1.480         0.987        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 28       0.987         0.493        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 29       0.493         0.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 30       0.000        -0.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 31      -0.500        -1.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 32      -1.000        -1.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 33      -1.500        -2.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 34      -2.000        -2.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 35      -2.500        -3.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 36      -3.000        -3.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 37      -3.500        -4.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 38      -4.000        -4.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 39      -4.500        -5.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 40      -5.000        -5.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 41      -5.500        -6.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 42      -6.000        -6.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 43      -6.500        -7.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 44      -7.000        -7.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 45      -7.500        -8.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 46      -8.000        -8.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 47      -8.500        -9.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 48      -9.000        -9.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 49      -9.500       -10.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 50     -10.000       -10.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 51     -10.500       -11.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 52     -11.000       -11.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 53     -11.500       -12.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 54     -12.000       -12.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 55     -12.500       -13.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 56     -13.000       -13.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 57     -13.500       -14.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 58     -14.000       -14.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 59     -14.500       -15.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 60     -15.000       -15.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 61     -15.500       -16.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 62     -16.000       -16.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 63     -16.500       -17.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 64     -17.000       -17.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 65     -17.500       -18.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 66     -18.000       -18.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 67     -18.500       -19.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 68     -19.000       -19.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 69     -19.500       -20.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 70     -20.000       -20.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 71     -20.500       -21.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 72     -21.000       -21.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 73     -21.500       -22.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 74     -22.000       -22.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 75     -22.500       -23.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 76     -23.000       -23.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 77     -23.500       -24.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 78     -24.000       -24.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 79     -24.500       -25.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 80     -25.000       -25.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 81     -25.500       -26.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 82     -26.000       -26.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 83     -26.500       -27.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 84     -27.000       -27.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 85     -27.500       -28.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 86     -28.000       -28.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 87     -28.500       -29.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 88     -29.000       -29.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 89     -29.500       -30.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 90     -30.000       -30.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 91     -30.500       -31.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 92     -31.000       -31.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 93     -31.500       -32.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 94     -32.000       -32.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 95     -32.500       -33.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 96     -33.000       -33.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 97     -33.500       -34.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 98     -34.000       -34.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 99     -34.500       -35.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 100    -35.000       -35.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 101    -35.500       -36.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 102    -36.000       -36.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 103    -36.500       -37.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 104    -37.000       -37.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 105    -37.500       -38.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 106    -38.000       -38.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 107    -38.500       -39.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 108    -39.000       -39.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 109    -39.500       -40.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 110    -40.000       -40.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 111    -40.500       -41.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 112    -41.000       -41.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 113    -41.500       -42.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 114    -42.000       -42.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 115    -42.500       -43.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 116    -43.000       -43.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 117    -43.500       -44.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 118    -44.000       -44.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 119    -44.500       -45.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 120    -45.000       -45.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 121    -45.500       -46.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 122    -46.000       -46.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 123    -46.500       -47.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 124    -47.000       -47.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 125    -47.500       -48.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 126    -48.000       -48.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 127    -48.500       -49.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 128    -49.000       -49.500        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07
# 129    -49.500       -50.000        0.0           0.0           2.0        1.000000e-10   3.141593  0.785398  2.487006e+07

# %%
df = modelList[9].get_soil_properties()
df.loc[df['x_top [m]'] == -2.00]
# Out:
#     x_top [m]  x_bottom [m]  Top soil layer [m]  Unit Weight [kN/m3]  \
# 34       -2.0          -2.5                 0.0                  7.0
#
#     xg_top [m]  xg_bottom [m]  sigma_v top [kPa]  sigma_v bottom [kPa]
# 34        -2.0           -2.5               14.0                  17.5
